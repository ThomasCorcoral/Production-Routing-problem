# %%
using IterTools
using JuMP
using CPLEX
using Combinatorics

include("PDI1NoBranch.jl")
include("utils.jl")
include("PDI_BC.jl")
# Out:
# PDI_BC2 (generic function with 1 method)

# %%
PDI_BC2(Read_PRP_instance("../PRP_instances/A_014_#ABS1_15_1.prp"))
# Out:
# Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# CPXPARAM_Threads                                 1
# CPXPARAM_TimeLimit                               600
# CPXPARAM_MIP_Tolerances_Integrality              1.0000000000000001e-15
# Generic callback                                 0x20
# Tried aggregator 2 times.
# MIP Presolve eliminated 190 rows and 94 columns.
# MIP Presolve modified 1299 coefficients.
# Aggregator did 15 substitutions.
# Reduced MIP has 335 rows, 1607 columns, and 3171 nonzeros.
# Reduced MIP has 1350 binaries, 96 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (2.81 ticks)
# Probing time = 0.01 sec. (2.01 ticks)
# Tried aggregator 2 times.
# Aggregator did 12 substitutions.
# Reduced MIP has 323 rows, 1595 columns, and 3159 nonzeros.
# Reduced MIP has 1350 binaries, 150 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (1.81 ticks)
# Probing time = 0.01 sec. (1.99 ticks)
# Clique table members: 177.
# ...
