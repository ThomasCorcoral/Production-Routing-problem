# %%
import Pkg
Pkg.add("FileIO")

# %%
include("../readPRP.jl")
include("../utils.jl")
# Out:
# generate_coords (generic function with 1 method)

# %%
"""include("VRP_Heuristiques.jl")
VRP_iteratif(data, demande, t, heuristique, heurTsp)"""
# Out:
# "include(\"VRP_Heuristiques.jl\")\nVRP_iteratif(data, demande, t, heuristique, heurTsp)"

# %%
file = "../../PRP_instances/A_014_ABS1_15_3.prp"
# file = "../../PRP_instances/A_100_ABS94_100_1.prp"
# file = "../../PRP_instances/B_050_instance5.prp"
# file = "../../PRP_instances/B_200_instance16.prp"
heuristique = "CW"
# Out:
# "CW"

# %%
include("PDI.jl")
PDI_H(file, heuristique)
# Out:
# 28147.0

# %%
using FileIO

display("image/png", read("log/B_050_instance5/t_3.png"))
